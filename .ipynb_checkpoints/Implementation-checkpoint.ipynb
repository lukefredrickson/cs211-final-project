# %%
# Load the data and libraries
import pandas as pd
import numpy as np
import random
from scipy import stats
import matplotlib.pyplot as plt
from functools import reduce
plt.style.use('seaborn-whitegrid')

# %%
# Helpful functions

def laplace_mech(v, sensitivity, epsilon):
    return v + np.random.laplace(loc=0, scale=sensitivity / epsilon)


def laplace_mech_vec(vec, sensitivity, epsilon):
    return [v + np.random.laplace(loc=0, scale=sensitivity / epsilon) for v in vec]


# preserves epsilon-differential privacy
def above_threshold(queries, df, T, epsilon):
    T_hat = T + np.random.laplace(loc=0, scale = 2/epsilon)
    
    for idx, q in enumerate(queries):
        nu_i = np.random.laplace(loc=0, scale = 4/epsilon)
        if q(df) + nu_i >= T_hat:
            return idx
    return -1 # the index of the last element


def auto_avg(df, epsilon):
    def create_query(b):
        return lambda df: df.clip(lower=0, upper=b).sum() - df.clip(lower=0, upper=b+1).sum()
    # Construct the stream of queries
    bs = np.logspace(0,6,1000)
    queries = [create_query(b) for b in bs]
    # Run AboveThreshold, using 1/3 of the privacy budget, to find a good clipping parameter
    epsilon_svt = epsilon / 3
    final_b = bs[above_threshold(queries, df, 0, epsilon_svt)]
    # Compute the noisy sum and noisy count, using 1/3 of the privacy budget for each
    epsilon_sum = epsilon / 3
    epsilon_count = epsilon / 3
    noisy_sum = laplace_mech(df.clip(lower=0, upper=final_b).sum(), final_b, epsilon_sum)
    noisy_count = laplace_mech(len(df), 1, epsilon_count)
    return noisy_sum/noisy_count


def score(df, key, option):
    return len(df[df[key] == option])


def report_noisy_max(df, key, score, sensitivity, epsilon):
    options = df[key].unique().tolist()
    scores = [score(df, key, option) for option in options]
    noisy_scores = [laplace_mech(score, 1, epsilon) for score in scores]
    max_score = np.max(noisy_scores)
    max_score_idx = noisy_scores.index(max_score)
    return options[max_score_idx]


def pct_error(orig, priv):
    return np.abs(orig - priv)/orig * 100.0

# %%
# Import dataset
payroll = pd.read_csv('./Citywide_Payroll_Data__Fiscal_Year_2020.csv', low_memory=False)
# add a Total Paid col, sum of all pay (regular, OT, other)
payroll['Total Paid'] = payroll['Regular Gross Paid'] + payroll['Total OT Paid'] + payroll['Total Other Pay']
payroll
# Out:
#         Fiscal Year  Payroll Number            Agency Name  Last Name  \
# 0              2020             2.0    OFFICE OF THE MAYOR   FULEIHAN
# 1              2020             2.0    OFFICE OF THE MAYOR  DE BLASIO
# 2              2020             2.0    OFFICE OF THE MAYOR     ANGLIN
# 3              2020             2.0    OFFICE OF THE MAYOR   THOMPSON
# 4              2020             2.0    OFFICE OF THE MAYOR       BEEN
# ...             ...             ...                    ...        ...
# 590205         2020           996.0  NYC HOUSING AUTHORITY   HOLLOWAY
# 590206         2020           996.0  NYC HOUSING AUTHORITY    WATKINS
# 590207         2020           996.0  NYC HOUSING AUTHORITY      GREEN
# 590208         2020           996.0  NYC HOUSING AUTHORITY      SCOTT
# 590209         2020           996.0  NYC HOUSING AUTHORITY     ISAACS
#
#          First Name Mid Init Agency Start Date Work Location Borough  \
# 0              DEAN        A        12/31/2017             MANHATTAN
# 1              BILL      NaN        01/01/2014             MANHATTAN
# 2             LAURA        L        01/03/2017             MANHATTAN
# 3             JAMES        P        03/12/2018             MANHATTAN
# 4             VICKI        L        02/07/2017             MANHATTAN
# ...             ...      ...               ...                   ...
# 590205       REESHA        Y        04/18/2019             MANHATTAN
# 590206  CHRISTOPHER        T        05/14/2012                 BRONX
# 590207     DANIELLE        E        05/14/2012                QUEENS
# 590208     PRECIOUS      NaN        03/25/2019              BROOKLYN
# 590209      EUNIQUE      NaN        05/08/2017              BROOKLYN
#
#          Title Description Leave Status as of June 30  Base Salary  \
# 0       FIRST DEPUTY MAYOR                     ACTIVE     291139.0
# 1                    MAYOR                     ACTIVE     258750.0
# 2             DEPUTY MAYOR                     ACTIVE     251982.0
# 3             DEPUTY MAYOR                     ACTIVE     251982.0
# 4             DEPUTY MAYOR                     ACTIVE     251982.0
# ...                    ...                        ...          ...
# 590205  CITY SEASONAL AIDE                     CEASED      27375.0
# 590206           CARETAKER                     CEASED      43941.0
# 590207           CARETAKER                     CEASED      43941.0
# 590208           CARETAKER                     CEASED      31286.0
# 590209           CARETAKER                     CEASED      37434.0
#
#               Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  \
# 0             per Annum         1820.0           286715.07       0.0
# 1             per Annum         1820.0           257351.53       0.0
# 2             per Annum         1820.0           248153.39       0.0
# 3             per Annum         1820.0           248153.39       0.0
# 4             per Annum         1820.0           243097.64       0.0
# ...                 ...            ...                 ...       ...
# 590205  Prorated Annual          -63.0             -607.41       0.0
# 590206        per Annum          -80.0            -3370.82       0.0
# 590207        per Annum          -80.0            -1685.41      -5.0
# 590208        per Annum         -160.0            -2400.02       0.0
# 590209        per Annum          -96.0             2898.08       0.0
#
#         Total OT Paid  Total Other Pay  Total Paid
# 0                0.00             0.00   286715.07
# 1                0.00          1500.00   258851.53
# 2                0.00             0.00   248153.39
# 3                0.00             0.00   248153.39
# 4                0.00             0.00   243097.64
# ...               ...              ...         ...
# 590205           0.00         -1020.00    -1627.41
# 590206           0.00          1626.15    -1744.67
# 590207        -184.14             0.00    -1869.55
# 590208           0.00             0.00    -2400.02
# 590209           0.00         -9044.19    -6146.11
#
# [590210 rows x 18 columns]

# %%
# get a differentially private count of number of employees per agency
# privacy cost = epsilon
def dp_agency_sizes(agencies, epsilon):
    sensitivity = 1
    keys = agencies.groupby('Agency Name').size().keys().to_list()
    counts = agencies.groupby('Agency Name').size().to_list()
    dp_counts = laplace_mech_vec(counts, sensitivity, epsilon)
    dp_agency_sizes = [(keys[i], dp_counts[i]) for i in range(0, len(keys))]
    return pd.DataFrame(dp_agency_sizes, columns=['Agency Name', 'DP Agency Size'])

# %%
# Select the agencies with between `lower` and `upper` employees
# privacy cost = epsilon
def select_agencies_by_size(lower, upper, epsilon):
    s = dp_agency_sizes(payroll, epsilon)
    selected_agencies = s.where(s['DP Agency Size'] > lower).where(s['DP Agency Size'] < upper).dropna()
    return selected_agencies

# %%
# get a non-differentially private mean column value per agency
def get_mean_value(agencies, key):
    mean_tuple = [(a, payroll[payroll['Agency Name'] == a][key].mean()) for a in agencies['Agency Name']]
    mean = pd.DataFrame(mean_tuple, columns=['Agency Name', 'Mean ' + key])
    return mean

# %%
# get a differentially private mean column value per agency
# privacy cost = epsilon
def get_dp_mean_value(agencies, key, epsilon):
    epsilon_i = float(epsilon)/len(agencies)
    dp_mean_tuple = [(a, auto_avg(payroll[payroll['Agency Name'] == a][key], epsilon_i)) for a in agencies['Agency Name']]
    dp_mean = pd.DataFrame(dp_mean_tuple, columns=['Agency Name', 'DP Mean ' + key])
    return dp_mean

# %%
# get total pay by agency (dp and non-dp, and % error between the two)
# privacy cost = epsilon
def get_pay_by_agency(selected_agencies, epsilon):
    mean_gross_pay = get_mean_value(selected_agencies, 'Total Paid')
    dp_mean_gross_pay = get_dp_mean_value(selected_agencies, 'Total Paid', epsilon)
    # merge dfs
    dfs = [selected_agencies, mean_gross_pay, dp_mean_gross_pay]
    merged = reduce(lambda left,right: pd.merge(left,right,on=['Agency Name'], how='outer'), dfs)
    merged['% Error Total Paid'] = pct_error(merged['Mean Total Paid'], merged['DP Mean Total Paid'])
    return merged

# %%
# privacy cost = epsilon
def get_max_in_cols_by_agency(selected_agencies, keys, epsilon):
    columns = { 'Agency Name': selected_agencies['Agency Name'] }
    sensitivity = 1
    epsilon_i = float(1)/len(keys)/len(selected_agencies)
    for key in keys:
        col = 'Most Common {}'.format(key)
        columns[col] = []
        for agency in selected_agencies['Agency Name']:
            noisy_max_value = report_noisy_max(payroll[payroll['Agency Name'] == agency], key, score, sensitivity, epsilon_i)
            columns[col].append(noisy_max_value)
    return pd.DataFrame(columns)

# %%
# End of function definitions

# %%
# select agencies with a decent number of employees. [500, 1000] is a good range for demonstration purposes
# if the following functions take too long, modify the min and max agency sizes to be smaller
epsilon = 1
agency_size_min = 500
agency_size_max = 1000
selected_agencies = select_agencies_by_size(agency_size_min, agency_size_max, epsilon)

# %%
# Uncomment the following line to view a list of all 156 agencies:
# payroll['Agency Name'].unique().tolist()

# %%
# If you'd like to run the following queries on specific agencies of your choosing,
# uncomment the last line and add the agencies you're interested in to custom_agencies.
custom_agencies = ['OFFICE OF THE MAYOR', 'TAXI & LIMOUSINE COMMISSION', 'CITY COUNCIL']
epsilon = 1
# selected_agencies = dp_agency_sizes(payroll[payroll['Agency Name'].isin(custom_agencies)], epsilon)

# %%
# get data on mean total pay by agency
epsilon = 8
pay_by_agency = get_pay_by_agency(selected_agencies, epsilon)

# %%
# get data on most common values per column by agency
epsilon = 2
columns = ['Work Location Borough', 'Title Description', 'Pay Basis']
max_in_cols_by_agency = get_max_in_cols_by_agency(selected_agencies, columns, epsilon)

# %%
merged = pay_by_agency.merge(max_in_cols_by_agency, on='Agency Name')
merged
# Out:
#                      Agency Name  DP Agency Size  Mean Total Paid  \
# 0      ADMIN TRIALS AND HEARINGS      727.158346     47898.380603
# 1              BOARD OF ELECTION      984.923752     52825.508438
# 2  DEPT OF YOUTH & COMM DEV SRVS      700.802161     67037.057518
# 3   DISTRICT ATTORNEY QNS COUNTY      864.971889     73217.582994
# 4      GUTTMAN COMMUNITY COLLEGE      794.976086     21923.908465
# 5   NYC EMPLOYEES RETIREMENT SYS      508.680264     68654.264882
# 6      OFFICE OF THE COMPTROLLER      935.884879     74769.380299
# 7            OFFICE OF THE MAYOR      800.631025     68114.407462
# 8    TAXI & LIMOUSINE COMMISSION      883.650254     47157.765607
#
#    DP Mean Total Paid  % Error Total Paid Most Common Work Location Borough  \
# 0        47740.167274            0.330310                         MANHATTAN
# 1        50516.778278            4.370484                         MANHATTAN
# 2        66743.508999            0.437890                         MANHATTAN
# 3        72039.411179            1.609138                            QUEENS
# 4        22547.880278            2.846079                         MANHATTAN
# 5        66436.106188            3.230912                          BROOKLYN
# 6        74231.482062            0.719410                         MANHATTAN
# 7        66485.961082            2.390752                         MANHATTAN
# 8        47320.384386            0.344840                            QUEENS
#
#   Most Common Title Description Most Common Pay Basis
# 0               HEARING OFFICER              per Hour
# 1               TEMPORARY CLERK             per Annum
# 2           COMMUNITY ASSOCIATE             per Annum
# 3   ASSISTANT DISTRICT ATTORNEY             per Annum
# 4             COLLEGE ASSISTANT              per Hour
# 5                 STAFF ANALYST             per Annum
# 6           PUBLIC RECORDS AIDE             per Annum
# 7             SPECIAL ASSISTANT             per Annum
# 8  TAXI AND LIMOUSINE INSPECTOR             per Annum
